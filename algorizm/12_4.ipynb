# %%
def linear_search(arr, target):
    for i, v in enumerate(arr):
        if v == target:
            return i
    return -1

# %%
import random
N = 100000000
arr = [random.randint(0,1000000) for _ in range(N)]

# for i in range(10000):
    # arr.append(i**2)
# linear_search(arr, 9999999)
# binaly_search(arr, 9999999)
# insertion_sort(arr)
# super_sort(arr)
probrem_1(arr, 5)
# probrem_2(arr, 7)

# %%
def binaly_search(arr, target):
    left, right = 0, len(arr)-1
    while left <= right:
        mid = (left+right) //2
        if arr[mid] == target:
            return mid
        elif arr[mid] < target:
            left = mid + 1
        else:
            right = mid -1
    return -1

# %%
def insertion_sort(arr):
    for i in range(1, len(arr)):
        key = arr[i]
        j = i - 1
        while j >= 0 and arr[j] > key:
            arr[j+1] = arr[j]
            j -= 1
        arr[j+1] = key
    return arr

# %%
def super_sort(arr):
    return sorted(arr)

# %%
def probrem_1(arr, target):
    for i, v in enumerate(arr):
        if v == target:
            return i
    return -1

# %%
def probrem_2(arr, target):
    left, right = 0, len(arr)-1
    while left != right:
        key = ( left + right )// 2
        if arr[key] > target:
            right = key-1
        elif arr[key] < target:
            left = key+1
        else:
            return key
    return -1

# %%
def probrem_3(arr):
    for i in range(1, len(arr)):
        key = arr[i]
        j = i-1
        while j >= 0 and a[j] > key:
            a[j+1] = a[j]
            j -= 1
        a[j+1] = key
    return arr
